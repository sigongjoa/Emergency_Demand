# %% [markdown]
# # 2022-11-11
# 현재 계산한 f1 score를 각 동별 그리고, 전체 데이터에 대해서 option에 대해서 df로 만들기(f1 score를 기준으로 정렬)
#
# ### df sample
#
# |  | ewma | factor | lr | optimizer | f1_score |
# |---|---|---|---|---|---|
# | 1 | alpha | 3 | 0.01 | adam | 0.09 |
# | ... |  |  |  |  |  |
# | n | com | 2 | 0.1 | ranger | 0.01 |
#
# 메모리를 많이 사용해서 그런지 주피터 커널이 자꾸 꺼짐 -> 그래서 f1-score 계산시 마다 csv로 저장하는 식으로 주피터 커널이 꺼져서 재시작해도 바로 이어서 df를 만들 수 있도록 만듬
#
# > result_notebook : http://202.31.200.194:8888/notebooks/NPLAB-NAS/Members/SEO/Emergency_Demand/TFT/2022_11_09_TEST_f1score/result_df.ipynb
