# %% [markdown]
# # attetion 32 trials
#
#
# | trial | epcoh | attention_head | hidden_size | model_path                                                          |
# |-------|-------|----------------|-------------|---------------------------------------------------------------------|
# | 0     | 300   | 32             | 128         | test/lightning_logs/version_16/checkpoints/epoch=299-step=1500.ckpt |
# | 1     | 100   | 32             | 16          | test/lightning_logs/version_18/checkpoints/epoch=99-step=500.ckpt   |
# | 2     | 100   | 32             | 32          | 'test/lightning_logs/version_19/checkpoints/epoch=99-step=500.ckpt' |
# | 3     | 100   | 32             | 64          | test/lightning_logs/version_22/checkpoints/epoch=99-step=500.ckpt   |
# | 4     | 100   | 32             | 128         | 'test/lightning_logs/version_23/checkpoints/epoch=99-step=500.ckpt' |

# %% [markdown]
# # result 1 : 300 , 32, 128
# |50%|70%|
# |--|--|
# |![](https://i.imgur.com/gayNTa4.png)|![](https://i.imgur.com/u41DUMk.png)|
#
# # result 2 : 100 , 32, 16
# |50%|70%|
# |--|--|
# |![](https://i.imgur.com/Kw4K8XR.png)|![](https://i.imgur.com/uHeUDoT.png)|
#
# # result 3 : 100, 32, 32
# |50%|70%|
# |--|--|
# |![](https://i.imgur.com/WolBTOs.png)|![](https://i.imgur.com/A4XZZET.png)|
#
# # result 4 : 100 , 32 , 64
# |50%|70%|
# |--|--|
# |![](https://i.imgur.com/Jst8cUg.png)|![](https://i.imgur.com/5ytVsOG.png)|
#
# # result 5 : 100 , 32 , 128
# |50%|70%|
# |--|--|
# |![](https://i.imgur.com/ItPNgWz.png)|![](https://i.imgur.com/yCufiFI.png)|

# %% [markdown]
# # ----------------------------------------------------------------------------------------------
#
#
# # result 1
# ![](https://i.imgur.com/gayNTa4.png)
# ![](https://i.imgur.com/u41DUMk.png)
#
#
# # result 2
# ![](https://i.imgur.com/Kw4K8XR.png)
# ![](https://i.imgur.com/uHeUDoT.png)
#
# # result 3
# ![](https://i.imgur.com/WolBTOs.png)
# ![](https://i.imgur.com/A4XZZET.png)
#
# # result 4
# ![](https://i.imgur.com/Jst8cUg.png)
# ![](https://i.imgur.com/5ytVsOG.png)
#
# # result 5
# ![](https://i.imgur.com/ItPNgWz.png)
# ![](https://i.imgur.com/yCufiFI.png)
