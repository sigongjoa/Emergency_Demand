# %% [markdown]
# # trial setting
#
# hparmas를 변경하면서 output의 scale확인
#
# min_scale : qunail이 50%에서의 output plot
#
# |version|epoch|attetion_head|hidden_size|optimizer|min_scale|model_path|
# |--|--|--|--|--|--|--|
# |0|100|4|16|ranger|0.00175|/home/nplab/NPLAB-NAS/Members/SEO/TFT/TEST_hparams/lightning_logs/version_0/checkpoints/epoch=99-step=10000.ckpt|
# |1|100|4|16|Radam|0.0025|/home/nplab/NPLAB-NAS/Members/SEO/TFT/TEST_hparams/lightning_logs/version_2/checkpoints/epoch=99-step=10000.ckpt|
# |1|100|32|16|Radam|0.0.0175|/home/nplab/NPLAB-NAS/Members/SEO/TFT/TEST_hparams/lightning_logs/version_9/checkpoints/epoch=99-step=10000.ckpt|
# |1|100|64|16|Radm|0.025|test/lightning_logs/version_1/checkpoints/epoch=99-step=500.ckpt|
# |1|100|64|32|Radm|0.0015|test/lightning_logs/version_4/checkpoints/epoch=99-step=500.ckpt|
# |1|100|64|64|Radm|0.0015|test/lightning_logs/version_6/checkpoints/epoch=99-step=500.ckpt|
# |1|300|16|16|Radm|None|'test/lightning_logs/version_11/checkpoints/epoch=299-step=1500.ckpt'
# |

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d6579f534729> in <module>
# ----> 1 import tensorflow
#
# ModuleNotFoundError: No module named 'tensorflow'

# %% [markdown]
# # 0 : default
# ![](https://i.imgur.com/eKpj9Kk.png)
#
#
# # 1 : RAdam
# ![](https://i.imgur.com/WVHfILu.png)
#
# # 2 : attention_head 32 , hidden_size 16
# ![](https://i.imgur.com/Iv26Pzv.png)
#
# # 3 : attention_head 64 , hidden_size 16
# ![](https://i.imgur.com/M8j87hR.png)
#
# # 4 : attention_head 32 , hidden_size 32
# ![](https://i.imgur.com/I8jxxtf.png)
#
# # 6 : attention_head 32 , hidden_size 64
# ![](https://i.imgur.com/Qaogzx9.png)
#
# # 6 : attention_head 16 , hidden_size 16 , epoch 300
#
# ![](https://i.imgur.com/ZSUFaxo.png)
