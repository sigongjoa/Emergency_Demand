# %%
# jupyter notebook 전체화면으로 변경  
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# # 2022-11-07
# 기존의 학습은 lr이 낮아서 특징적인 패턴을 학습 하지 못했음 + 다른 변수들을 제외하고 학습을 했음
# lr을 1, 0.1, 0.01 , 학습 변수를 다 넣은뒤 학습을 진행
# 좋은 성능을 보이는 lr에 대해서 다른 ewma iter1에 적용
#
# 추가로 optimzer로 테스트
#
# > result alll : http://202.31.200.194:8888/notebooks/NPLAB-NAS/Members/SEO/Emergency_Demand/TFT/TEST_ewma/result_view_html.ipynb#all-plot
#
# # ewma & lr Best
# optimizer = '`RAda`
#
# ![](https://i.imgur.com/4ySoqU3.png)
# ![](https://i.imgur.com/GGBdnsx.png)
# ![](https://i.imgur.com/4SWTPsa.png)
# ![](https://i.imgur.com/PmeoNaz.png)
# ![](https://i.imgur.com/MqUrAMC.png)
# ![](https://i.imgur.com/c0up7Ln.png)
# ![](https://i.imgur.com/HqL2WML.png)
# ![](https://i.imgur.com/pTPUMOu.png)
# ![](https://i.imgur.com/0i8nL9c.png)
# ![](https://i.imgur.com/cCvu0M4.png)
# ![](https://i.imgur.com/3jXyUnz.png)
# ![](https://i.imgur.com/wTvqplM.png)
# ![](https://i.imgur.com/tRVLxI7.png)
# ![](https://i.imgur.com/VcqCUrS.png)
#
#
# # optim & lr Best
#
# data = `alpha1/02`
#
# ![](https://i.imgur.com/jHrxGec.png)
# ![](https://i.imgur.com/6bnhTq2.png)
# ![](https://i.imgur.com/xBkwec4.png)
# ![](https://i.imgur.com/OsA1DbK.png)
# ![](https://i.imgur.com/s8CViuV.png)
# ![](https://i.imgur.com/gyFTLxy.png)
