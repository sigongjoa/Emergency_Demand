# %% [markdown]
# # 2022-11-09
#
# best_study에 대해서 F1 score 계산 및 시각화
#
# * 각 동별
# * 전체 동
#
#
# ewma 옵션 확인(plot) , optimzer 옵션 확인(plot) -> best study 생성
#
# 데이터 추가 후 학습 진행(기상청에 전화후 결측치 데이터 확인)

# %% [markdown]
# ## f1 score
#
# #### confusion matrix(125개)
# > test notebook : http://202.31.200.194:8888/notebooks/NPLAB-NAS/Members/SEO/Emergency_Demand/TFT/2022_11_02_TEST_ewma/result_all.ipynb
#
# 다음과 같이 시각화
# ![](https://i.imgur.com/EHqt4J2.png)
# ![](https://glassboxmedicine.files.wordpress.com/2019/02/confusion-matrix.png?w=816)
#
# 아래와 같은 hparams에 대해서 학습(100 epoch)
# emwa:
# ```python
# ['alpha1/03.csv', 'alpha1/04.csv', 'alpha1/05.csv', 'com1/2.csv','com1/3.csv', 'span1/4.csv', 'span1/5.csv']
# ```
#
# lr :
# ```python
# [0.1  , 0.01 , 0.001]
# ```
#
# optimizer :
# ```python
# ['Adam', 'AdamW', 'Adamax', 'NAdam', 'RAdam', 'ranger']
# ```

# %% [markdown]
# ## setting(ewma, optimizer, lr)
#
#
#
# ### ewma & lr
# ewma와 lr를 변경해 가면서 성능이 좋게 보이는 경우만 선택
# ![](https://i.imgur.com/Toucu6i.png)
# ![](https://i.imgur.com/imyga2N.png)
# ![](https://i.imgur.com/zTYa2Yq.png)
# ![](https://i.imgur.com/lNV8klW.png)
# ![](https://i.imgur.com/6G0VvxA.png)
# ![](https://i.imgur.com/wbHUJJq.png)
# ![](https://i.imgur.com/Xgrs0hZ.png)
# ![](https://i.imgur.com/sQI2e0x.png)
#
# ### optim & lr
# optimzer와 lr를 변경해 가면서 성능이 좋게 보이는 경우만 선택
#
# ![](https://i.imgur.com/WPvJhp6.png)
# ![](https://i.imgur.com/oZyIuh8.png)
# ![](https://i.imgur.com/Maq7Vzj.png)
# ![](https://i.imgur.com/hselJE2.png)
# ![](https://i.imgur.com/eR24tR2.png)

# %% [markdown]
# ## new data
# 현재 기상 데이터의 결측치 때문에 train data를 생성하지 못하고 있었음
# 확인해 보니 2016년 이후로 월별 결측치가 없음
# 2016년 이후로 데이터 데이터 생성
#
# > weather 확인 : http://202.31.200.194:8888/notebooks/NPLAB-NAS/Members/SEO/Emergency_Demand/data/weather_view.ipynb
