# %% [markdown]
# # 2022-11-21
#
# ## check process
# 다음에 단계를 진행하기전에 지금 너무 예측을 잘하고 있어서 process자체를 리뷰를 할 필요가 있어 보임
# * 전체 process에 대해서 notebook file로 만들기
# * 데이터를 직접 열어 볼 수 있도록 만들기
# * data , training , result 3개로 분리해서 각자의 flow를 시각화 추가
#
#
# > notebook : http://202.31.200.194:8888/notebooks/NPLAB-NAS/Members/SEO/kit-data-anaysis/processing_DataFrame.ipynb
