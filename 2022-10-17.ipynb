# %% [markdown]
# # month prediction
#
# 현재는 일주일을 보고 하루를 예측하도록 하고 있음
# 하루를 연속적으로 20일 동안 예측(30일로 예측을 했을 때 에러가 남)
# > notebook : http://202.31.200.194:8889/notebooks/NPLAB-NAS/Members/SEO/Emergency_Demand/TFT/TEST_graph/compare_nei.ipynb#dong-plot-sample
#
#
# # nei k prediction plot sample
# plot을 할때 모든 nei을 하나의 plot으로 했을 때 복잡해서 하나의 nei k 일때만 plot
# > 모든 행정동 plot : http://202.31.200.194:8889/notebooks/NPLAB-NAS/Members/SEO/Emergency_Demand/TFT/TEST_graph/compare_nei.ipynb#dong-plot-all
#
# ### nei 0 , nei1, nei2 plot
# ![](https://i.imgur.com/NsbUx6y.png)
#
# ### nei 0  plot
# ![](https://i.imgur.com/wKsE45P.png)
#
# ### nei 1  plot
# ![](https://i.imgur.com/n381UNz.png)
#
# ### nei 2  plot
# ![](https://i.imgur.com/JEL9VLN.png)
