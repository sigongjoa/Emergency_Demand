# %% [markdown]
# # max_prediction_length = 24
# | trial                      | attention_head     | hidden_size | model_path
# |----------------------------|--------------------|-------------|--------------------------------------------------------------------
# | 0                          | 16                 | 16          | 'test/lightning_logs/version_1/checkpoints/epoch=99-step=500.ckpt' |
# | 1                          | 16                 | 32          | 'test/lightning_logs/version_2/checkpoints/epoch=99-step=500.ckpt' |
# | 2                          | 16                 | 64          | 'test/lightning_logs/version_3/checkpoints/epoch=99-step=500.ckpt'
#
#
# |50%|70%|
# |--|--|
# |![](https://i.imgur.com/4Mq3PRZ.png)|![](https://i.imgur.com/oowqunm.png)|
#
#
# |50%|70%|
# |--|--|
# |![](https://i.imgur.com/P1SB0xe.png)|![](https://i.imgur.com/5IGZaId.png)|
#
# |50%|70%|
# |--|--|
# |![](https://i.imgur.com/ES9SJ3F.png)|![](https://i.imgur.com/xgwOHse.png)|

# %% [markdown]
# # max_prediction_length = 24 , rouding
#
#
# | trial                      | attention_head     | hidden_size | model_path
# |--|---|--|----|
# | 0                          | 16                 | 16          | 'test/lightning_logs/version_6/checkpoints/epoch=99-step=500.ckpt' |
# | 1                          | 16                 | 32          | 'test/lightning_logs/version_5/checkpoints/epoch=99-step=500.ckpt' |
# | 2                          | 16                 | 64          | 'test/lightning_logs/version_4/checkpoints/epoch=99-step=500.ckpt'|
#
#
#
# |50%|70%|
# |--|--|
# |![](https://i.imgur.com/u6Xzvk7.png)|![](https://i.imgur.com/nhS2Wdj.png)|
#
# |50%|70%|
# |--|--|
# |![](https://i.imgur.com/7WXzpn6.png)|![](https://i.imgur.com/gbUIRSD.png)|
#
# |50%|70%|
# |--|--|
# |![](https://i.imgur.com/WpvE8sz.png)|![](https://i.imgur.com/XmvYSqK.png)|

# %% [markdown]
# # max_prediction_length = 24 , epoch 300
#
# | trial 	| epoch 	| attention_head 	| hidden_size 	| rounding 	| model_path                                                           	|
# |-------	|-------	|----------------	|-------------	|----------	|----------------------------------------------------------------------	|
# | 0     	| 300   	| 4              	| 16          	| O        	| 'test/lightning_logs/version_8/checkpoints/epoch=299-step=1500.ckpt' 	|
# | 1     	| 300   	| 4              	| 16          	| X        	| 'test/lightning_logs/version_9/checkpoints/epoch=299-step=1500.ckpt' 	|
#
# |50%|70%|
# |--|--|
# |![](https://i.imgur.com/QOCtrjF.png)|![](https://i.imgur.com/1Pvahgv.png)|
#
# |50%|70%|
# |--|--|
# |![](https://i.imgur.com/HmJF2lb.png)|![](https://i.imgur.com/iEKoLWm.png)|
