# %% [markdown]
# # 2022_12_23
#
# ## base model check
# * round_cut(0.5)을 기준으로 round_cut 이하는 0 , 이상은 1로 바꿔서 metric을 계산함
# * base model을 선택하기 위해서 각 round_cut(0.3, 0.5, 0.7 , 0.9)에 대해서 표로 만들기
#
# > result_notebook : http://202.31.200.194:8888/notebooks/NPLAa-NAS/Members/SEO/Emergency_Demand/TFT/2022_12_15_TEST_ewma_alpha/result_veiw.ipynb
#
# ## emergency check
# * 발생 빈도만을 사용하는데 어떤 사건인지 알 수 있도록 변경
# * interaction plot으로 구현 해야 해서 조금 나중에 처리
#
# ## new_data
# * 기존의 2021년도 데이터만 사용
# * 기존의 데이터와 새로 만든 2016년 ~ 2020년도 데이터 확인후 새로운 학습
#
#
# * 기존의(2021년도) 데이터 와 새로 만든(2016~ 2020년도) 데이터 비교
# > compare notebook : http://202.31.200.194:8888/notebooks/NPLAB-NAS/Members/SEO/Emergency_Demand/data/visualization.ipynb#temp-%EB%B9%84%EA%B5%90
#
#  기존 날씨 데이터는 바로 사용하면 되는데, 옛날 날씨 데이터는 시간대별로 예보값을 여러개를 사용함
#  예보값의 평균이나 최대값, 최빈값을 사용해서 처리하는데 이를 잘 조정해서 기존 날씨 데이터와 유사하게 만듬
# > 학습 결과 : http://202.31.200.194:8888/notebooks/NPLAB-NAS/Members/SEO/Emergency_Demand/TFT/2022_12_22_TEST_new_data_training/result_veiw.ipynb
#
# > 기존의 데이터로 학습 결과 : http://202.31.200.194:8888/notebooks/NPLAB-NAS/Members/SEO/Emergency_Demand/TFT/2022_12_15_TEST_ewma_alpha/result_veiw.ipynb
#
# * 데이터 양이 많아 졌으므로 다시 hparams 별로 최적의 hparmas 찾기
#
# ## additional variable
#
# * 추가 control variable(행사정보, 안전관리정보, 소방대상물 정보, 위험물 정보)를 전처리 후 학습
# * 추가 variable은 추가가 어려움
# * 강남동에 주유소가 몇개 생성되었는지는 확인이 가능하나 없어진 주요소가 몇개인지를 알 수가 없어서 시간에 따른 변화를 찾기가 힘듬
#
# * graph variable 추가(현재 h_dong에서 인접한 h_dong의 count 값의 합계를 사용)
#
# ## Refence Model
# 논문에 비교용으로 사용할 모델
#
# * XGBoost
# * multivariable lstm
#
# TFT와 비교
#
# ## Meeting
# * 추가 변수에 경우에는 기존의 방식대로 처리해도 별 상관은 없음(시간대별 추이가 아닌 상대적으로 위험물이 더 많은지 아닌지를 비교하기 위함)
# * Geo data 확인(행정동과 법정동을 지도에 시각화 한 후에 각 동별 포함관계를 파악)
