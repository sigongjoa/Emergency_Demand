# %% [markdown]
# # 2022_12_14
#
# ## ewma
# 지금 ewma를 적용하면 실제로 시간에 대한 control이 어려움
# ewma factor별로 시각화해서 얼마나 값이 올라가는지 확인
#
# plot 과 scatter 두 가지 버전으로 제작
#
# * 1월 5일 ~ 1월 7일
# * 1월 30일 ~ 2월 1일
# * 2월 19일 ~ 2월 20일
#
# 세 개의 구간으로 확인
#
# ### sample plot
#
# ![](https://i.imgur.com/qzaWUQ3.png)
# ![](https://i.imgur.com/tzjAxsM.png)
#
# > result notebook : http://202.31.200.194:8888/notebooks/NPLAB-NAS/Members/SEO/Emergency_Demand/TFT/2022_12_12_TEST_ewma_detail/ewma_detail_plot.ipynb
#
#
# ## add data
# 날씨 데이터를 확보 했고, 날씨 데이터를
# * duplicate
# * interploation
#
# 둘 다 적용 후 데이터 시각화
#
#
# ## meeting
# ewma를 다른 방식도 비슷해서
# alpha 0.3 , 0.5, 0.7에 대해서 학습하고 시각화
