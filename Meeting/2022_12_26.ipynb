# %% [markdown]
# # 2022_12_06
#
# ## geo data check
# 현재 행정동을 기준으로 데이터를 생성함
# 실제로 행정동은 29개 정도 되는데 인구 데이터 가 21개 동으로 데이터를 나타내서 이에 맞춰서 21개 동을 사용
# 실제 춘천시 행정동(29개)와  차이가 남
# 이를 지도로 시각화 이후에 처리 실제 춘천시 행정동에 맞도록 변경
#
# > 법정동(읍면동) shp 파일 : http://data.nsdi.go.kr/dataset/15145
#
# > 법정동(리) shp 파일 : http://data.nsdi.go.kr/dataset/12719
#
# > 행정동 shp 파일 : http://data.nsdi.go.kr/dataset/20171206ds00001
#
#
# > 법정동과 행정동 포함관계 확인 : http://202.31.200.194:8888/notebooks/NPLAB-NAS/Members/SEO/Emergency_Demand/MapVisiaulization/h_dong_STDG_CD.ipynb
#
#
# > 지도 시각화 result : http://202.31.200.194:8888/notebooks/NPLAB-NAS/Members/SEO/Emergency_Demand/MapVisiaulization/Map_visualation.ipynb
#
#
# ## weahter data
# 지금의 날씨 데이터는 단기 예보를 사용함
# 이는 (구)단기 예보와 단기 예보로 나뉨
# (구) 단기 예보는 3시간 단위로 예보값을 사용하고 있음
# 이를 사용할경우 데이터를 집계 해서 사용해야 해서 데이터 스케일의 차이가 나타남
# 기상청 실황 데이터로 처리함
#
# ## additional data
# 현재 사용할 수 있는 추가 데이터(행상, 위험물, 안전관리정보, 소방대상물 정보, 위험물 정보)를 기존의 처리 방식 그대로 처리
#
# ## meeting
# 우선 외부데이터(인구, 기상청 데이터가 행정동 기준으로 되어 있어서 행정동 기준으로 데이터 새로 생성(법정동 하면 target 값이 희소해짐)
#
# 기상청 실황 데이터 처리
