# %% [markdown]
# # 2023_01_06
#
# ## XGClassifier
# 기존의 XGRegressior에서 XGClassifier로 변경해서 학습 진행
# 이때 사건의 발생 여부에 따라서 1/0로 변경
#
# * metric을 다음과 같이변경?
#
#
# $metric = |TP * \alpha - TN|$
#
# 지금은 TN이 너무 많으므로 모델이 학습을 할 때는 TN이 높게 나오도록 학습을 함
# 정확도와 같은 metric은 높게 나오지만 예측을 잘 한다고 보기에는 어려움
# TP의 값 변화에 모델이 더 집중 할 수 있도록 변경
#
# > result_notebook : http://202.31.200.194:8888/notebooks/NPLAB-NAS/Members/SEO/Emergency_Demand/reference%20model/decision_tree_base_model_classification.ipynb
#
#
# $\alpha$값을100으로 줬는데 최적의 수를 계산할 수 있음
#
# ## MultivariateTSF
#
# > result_notebook : http://202.31.200.45:8888/notebooks/NPLAB-NAS/Members/SEO/Emergency_Demand/reference%20model/MultivariateTSF.ipynb
#
# ## all model hparams
#
# 비교를 위해서 metric,loss와 같은 설정들을 통일 시킬 필요가 있어 보임
#
#
# ## Meeting
# 내용이 많아서 정리 후에 다음 notebook에 기록
