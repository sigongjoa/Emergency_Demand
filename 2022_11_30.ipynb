# %% [markdown]
# # 2022_11_30
#
# 현재는 ewma는 앞에서 한번 뒤에서 한번 총 두번을 적용해서 정규분포의 꼴로 만들었다.
# 이렇게 한 후에 모델을 학습을 시키기고 예측을 한다면 TFT 모델은 조그만한 신호가 발생하더라도 쉽게 사건이 발생한다고 예측을 하고 있다
# (잘 맞추면 좋은거 아님?)
#
# 이를 ewma를 뒤에서만 나타나게 한번만 적용해서 다시 학습을 진행
#
# > ewma notebook : http://202.31.200.194:8888/notebooks/NPLAB-NAS/Members/SEO/Emergency_Demand/TFT/2022_11_28_TEST_ewma/ewma_plot.ipynb
