# %% [markdown]
# # 2022_12_02
#
# ## 기존의 rouding
#
# ![](https://i.imgur.com/HkZaaiG.png)
#
#
# ## rounding - thresholod
# 기존은 0.5로 threshold로 사용
# 원하는 수치를 넣어서 T/F로 변경
#
# > cut_off별 결과 : http://202.31.200.194:8888/notebooks/NPLAB-NAS/Members/SEO/Emergency_Demand/TFT/2022_11_23_TEST_best_hparams/test_post_processing_round.ipynb#cut-off-%EB%B3%84-plot
#
# * 결과 그래프(cut_off 미적용)
#
# ![](https://i.imgur.com/4TEdbWJ.png)
# ![](https://i.imgur.com/xlQ7k6n.png)
# ![](https://i.imgur.com/VWCGTo3.png)
# ![](https://i.imgur.com/FH1wF2E.png)
# ![](https://i.imgur.com/GvLkfdE.png)
# ![](https://i.imgur.com/P1isDbB.png)
# ![](https://i.imgur.com/dktmr61.png)
# ![](https://i.imgur.com/TlDV8mo.png)
# ![](https://i.imgur.com/5urY9B3.png)
#
#
#
#
# ## rounding - peak
# 현재 그래프는 진동을 하고 있는데 이때의 각 구간마다의 최대점만을 모은 후에 구간 최대점들중에서 최소값 이상인 값들만을 T로 바꾸는 방식
#
# > find_peak : https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.find_peaks.html
#
# 다음 함수를 이용해서 구간내의 peak값을 찾아서 바꿈
# 일정 값 이상에서만 peak를 가져와서 사용할 수 있음
#
# * 결과 그래프
#
# #### peak를 1로 했을 때로 test 진행
#
# ![](https://i.imgur.com/I54yHUt.png)
# ![](https://i.imgur.com/NoouvoE.png)
# ![](https://i.imgur.com/rVtKk5H.png)
#
#
#
# * params의 변화에 따른 값의 차이를 잘 보기 위해서 ewma 2번 적용한 model에서 테스트
#
# > rounding test notebook : http://202.31.200.194:8888/notebooks/NPLAB-NAS/Members/SEO/Emergency_Demand/TFT/2022_11_23_TEST_best_hparams/test_post_processing_round.ipynb
#
#
# ## hparams
# 기존에는 ewma, ewma_factor, optim , lr 에 대해서 f2_score를 이용해서 성능을 비교했음
# 학습이 덜 되는거 같은 느낌임
# ```python
# epochs = [100, 200,300, 400,500, 600 , 700, 800, 900]
# hidden_sizes = [8, 16, 32 ,48 ,  64, 80]
# atten_heads = [1, 2, 3, 4, 8 , 10, 12, 14, 16]
# batch_sizes = [2, 4, 6, 8, 12 ,16 , 20, 24, 28, 32, 48, 52 , 64]
# ```
#
# 를 비교해가면서 성능을 비교
# ### hparams 시각화
#
# #### epoch
# > plot notebook : http://202.31.200.194:8888/notebooks/NPLAB-NAS/Members/SEO/Emergency_Demand/TFT/2022_12_02_TEST_epcoh/result_post_processing_f2_peak.ipynb
#
# #### hidden_sizes
# > plot notebook : http://202.31.200.194:8888/notebooks/NPLAB-NAS/Members/SEO/Emergency_Demand/TFT/2022_12_02_TEST_hidden_size/result_post_processing_f2_peak.ipynb
#
# hidden_size가 8일 때가 가장 좋은 거 같음 ???
# 학습 패턴이 단순하기 때문에 hidden_size가 작을 때 좋은 성능을 보이는건가?
# hidden_size의 의미는?
#
# #### batch_size
# > plot notebook : http://202.31.200.194:8888/notebooks/NPLAB-NAS/Members/SEO/Emergency_Demand/TFT/2022_12_02_TEST_batch_size/result_post_processing_f2_peak.ipynb
#
# #### atten_head
# > plot notebook : http://202.31.200.194:8888/notebooks/NPLAB-NAS/Members/SEO/Emergency_Demand/TFT/2022_12_02_TEST_atten_head/result_post_processing_f2_peak.ipynb
#
#
# ## additional hparams
#
# 다음과 같은 hparams도 TEST 해볼만 함?
#
# > tft : https://pytorch-forecasting.readthedocs.io/en/stable/api/pytorch_forecasting.models.temporal_fusion_transformer.TemporalFusionTransformer.html
#
# * lstm_layer : lstm의 기능을 생각해봤을 때 lstm_layer가 많다면 더 이전의 정보에 대해서 접근 할 것임, 현재 데이터가 spare 하므로 조조금 더 넓은 범위를 봐야 하지 않을까?
# * dropout : over fiting test
# * causal_attention : 이해 못해서 궁금함
