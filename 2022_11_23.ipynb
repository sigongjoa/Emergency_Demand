# %% [markdown]
# # 2022-11-23
#
# 지금은 train data와 test 데이터를 같이 붙여서 ewma 적용후에 학습을 진행
# 이렇게 되었을 때 마지막 부분에서 ewma 값이 짤려서 train을 하는 경우가 발생 할 수도 있음(데이터 오염의 가능성)
#
# 이를 방지하기 위해서 train에만 ewma를 적용하고, test에는 ewma를 적용하지 않은 상태에서 prediction 진행
#
# > spilt test notebook : http://202.31.200.194:8888/notebooks/NPLAB-NAS/Members/SEO/Emergency_Demand/vadiation%20processing_split.ipynb
#
# split된 training result
# ![](https://i.imgur.com/guFMykW.png)
#
# 기존의 학습 방법을 사용한 result
# ![](https://i.imgur.com/pKvD2DM.png)
#
# > ewma_lr_optim에 대해서 TEST result :http://202.31.200.194:8888/view/NPLAB-NAS/Members/SEO/Emergency_Demand/TFT/2022_11_22_TEST_hparams1/result_test_ewma_lr_optim.html
#
# ![](https://i.imgur.com/EXTvGae.png)
