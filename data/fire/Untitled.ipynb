# %%
import os
test = os.listdir('weather')[0]
test
# Out:
# '│▓╗ъ╕щ_3╜├░г▒т┐┬_201501_201512.csv'

# %%
test.encode('euc-kr')
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-10-25ad921dd6a6> in <module>
# ----> 1 test.encode('euc-kr')
#
# UnicodeEncodeError: 'euc_kr' codec can't encode character '\u2593' in position 1: illegal multibyte sequence
