# %%
import pandas as pd

# %%
a = pd.read_csv('2015_2022_popl.csv')
b = pd.read_csv('popl_2014.csv')
c = pd.read_csv('popl_2010_2013.csv')

# %%
a['h_dong'].unique()
# Out:
# array(['신북읍', '동  면', '동산면', '신동면', '동내면', '남  면', '남산면', '서  면', '사북면',
#        '북산면', '소양동', '교  동', '조운동', '약사명동', '근화동', '후평1동', '후평2동', '후평3동',
#        '효자1동', '효자2동', '효자3동', '석사동', '퇴계동', '강남동', '신사우동'], dtype=object)

# %%
b['h_dong'].unique()
# Out:
# array(['신북읍', '동  면', '동산면', '신동면', '동내면', '남  면', '남산면', '서  면', '사북면',
#        '북산면', '소양동', '교  동', '조운동', '약사명동', '근화동', '후평1동', '후평2동', '후평3동',
#        '효자1동', '효자2동', '효자3동', '석사동', '퇴계동', '강남동'], dtype=object)

# %%
c['h_dong'].unique()
# Out:
# array(['신북읍', '동  면', '동산면', '신동면', '동내면', '남  면', '남산면', '서  면', '사북면',
#        '북산면', '소양동', '교  동', '조운동', '약사명동', '근화동', '후평1동', '후평2동', '후평3동',
#        '효자1동', '효자2동', '효자3동', '석사동', '퇴계동', '강남동'], dtype=object)
