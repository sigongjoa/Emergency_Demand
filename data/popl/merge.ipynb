# %%
import pandas as pd

# %%
a = pd.read_csv('2015_2022_popl.csv')
b = pd.read_csv('popl_2014.csv')
c = pd.read_csv('popl_2010_2013.csv')

# %%
result_df = pd.DataFrame()

# %%
result_df = pd.concat([result_df, c])
result_df = pd.concat([result_df, b])
result_df = pd.concat([result_df, a])
result_df = result_df[['REG_DTIME', 'h_dong', 'pops']]

# %%
result_df.to_csv('popl.csv',index=False)

# %%
result_df
# Out:
#                    REG_DTIME h_dong     pops
# 0        2010-01-01 00:00:00    신북읍   7284.0
# 1        2010-01-01 00:00:00   동  면   9728.0
# 2        2010-01-01 00:00:00    동산면   1562.0
# 3        2010-01-01 00:00:00    신동면   2526.0
# 4        2010-01-01 00:00:00    동내면  13165.0
# ...                      ...    ...      ...
# 1569620  2022-03-01 00:00:00   효자3동   4376.0
# 1569621  2022-03-01 00:00:00    석사동  34498.0
# 1569622  2022-03-01 00:00:00    퇴계동  48669.0
# 1569623  2022-03-01 00:00:00    강남동  22725.0
# 1569624  2022-03-01 00:00:00   신사우동  24571.0
#
# [5330450 rows x 3 columns]
