# %% [markdown]
# # 2022_11_18
#
# 현재 f1_score가 가장 좋은 setting
#
# ## remove tail
# |  | ewma | factor | lr | optim | f1_score |
# |---:|---:|---:|---:|---:|---:|
# | 27 | alpha | 04 | 0.010 | NAdam | 0.193044 |
#
# 위 setting에서 plotting을 해보면 그림과 같이
# ![](https://i.imgur.com/24Z6KDq.png)
# 발생을 잘 예측하지만 예측이 이후에도 값이 남아 있어서 FP가 높게 나오는 것을 확인 할 수 있다.
# 이를 확인하기 위해
# 1. 현재 plot에다가 원본 예측값을 추가
# 2. lr 세분화 (0.1 , 0.01, 0,001에서 , 0.1 , 0.05 , 0.01 , 0.005, 0.0001) in 27번 setting
#
# > result(HTML) : http://202.31.200.194:8888/view/NPLAB-NAS/Members/SEO/Emergency_Demand/TFT/2022_11_17_TEST_lr/result_all_dong_html.html
#
#
# lr을 0.1 ~ 0.01 사이의 값에 대해서 f1 score 비교
#
# ## data
# 1. 현재 데이터의 오염 여부 확인
# 2. 새롭게 추가할만한 데이터가 어떤 것이 있는지 확인

# %%
check is okay when dataloader insert one week unit
